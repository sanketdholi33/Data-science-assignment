# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=(10,5)
plt.rcParams['figure.dpi']=150
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Q9_b.csv',index_col=0)

# %%
df.head(10)
# Out:
#             SP         WT
# 1   104.185353  28.762059
# 2   105.461264  30.466833
# 3   105.461264  30.193597
# 4   113.461264  30.632114
# 5   104.461264  29.889149
# 6   113.185353  29.591768
# 7   105.461264  30.308480
# 8   102.598513  15.847758
# 9   102.598513  16.359484
# 10  115.645204  30.920154

# %%
# skewness Values
df.skew()
# Out:
# SP    1.611450
# WT   -0.614753
# dtype: float64

# %%
# Kurtosis Values
df.kurtosis()
# Out:
# SP    2.977329
# WT    0.950291
# dtype: float64

# %%
sns.histplot(data=df['SP'])
# Out:
# <Axes: xlabel='SP', ylabel='Count'>

# %%
sns.histplot(data=df['WT'])
# Out:
# <Axes: xlabel='WT', ylabel='Count'>

# %%
df.boxplot()
# Out:
# <Axes: >
