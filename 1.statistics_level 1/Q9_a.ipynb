# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=(10,5)
plt.rcParams['figure.dpi']=150
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Q9_a.csv',index_col=0)

# %%
df.head(10)
# Out:
#        speed  dist
# Index
# 1          4     2
# 2          4    10
# 3          7     4
# 4          7    22
# 5          8    16
# 6          9    10
# 7         10    18
# 8         10    26
# 9         10    34
# 10        11    17

# %%
df.describe()
# Out:
#            speed        dist
# count  50.000000   50.000000
# mean   15.400000   42.980000
# std     5.287644   25.769377
# min     4.000000    2.000000
# 25%    12.000000   26.000000
# 50%    15.000000   36.000000
# 75%    19.000000   56.000000
# max    25.000000  120.000000

# %%
df.skew()# Skewness values of Speed And Distance Column
# Out:
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
df.kurtosis()# Skewness values of Speed And Distance Column
# Out:
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
sns.histplot(data=df['speed'])
# Out:
# <Axes: xlabel='speed', ylabel='Count'>

# %%
sns.histplot(data=df['dist'])
# Out:
# <Axes: xlabel='dist', ylabel='Count'>

# %%
df.boxplot()
# Out:
# <Axes: >
